# %% [markdown]
# <a href="https://colab.research.google.com/github/amrita13/TacticalReadinessFOB/blob/main/DisplayFOBONMAP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# --- Step 1: Install dependencies (folium is usually preinstalled in Colab)
# !pip install folium

import pandas as pd
import folium

# --- Step 2: Create sample FOB dataset (50 entries shown here, extendable to 229)
data = {
    "FOB_Name": [f"FOB_{i:03d}" for i in range(1, 51)],
    "Latitude": [
        28.6139,19.0760,22.5726,13.0827,17.3850,26.9124,23.0225,21.1702,25.3176,27.1767,
        24.5854,15.2993,11.0168,9.9312,8.5241,10.8505,12.9716,18.5204,23.3441,26.8467,
        30.7333,31.1048,32.7266,34.0837,33.7782,27.5330,27.3314,27.7172,28.3949,27.2046,
        25.5941,24.7914,23.6102,22.8056,21.2514,20.9517,19.8135,18.7061,17.6868,16.5062,
        15.8281,14.4426,13.6288,12.2958,11.6643,10.7860,9.9252,8.7139,7.8780,6.9271
    ],
    "Longitude": [
        77.2090,72.8777,88.3639,80.2707,78.4867,75.7873,72.5714,72.8311,82.9739,78.0081,
        73.7125,74.1240,76.9558,76.2673,76.9366,76.2711,77.5946,73.8567,85.3096,80.9462,
        76.7794,77.1734,74.8570,74.7973,76.5762,88.5122,88.6130,85.3240,84.1240,77.4977,
        85.1376,85.0002,85.2799,86.2029,81.6296,85.0985,85.8312,84.4006,83.2185,80.6480,
        78.0373,79.9865,79.4192,76.6394,78.1460,78.7047,78.1198,77.7567,77.3900,79.8612
    ],
    "DL": [0.82,0.85,0.81,0.83,0.80,0.84,0.82,0.83,0.81,0.82,
           0.84,0.80,0.83,0.82,0.81,0.83,0.84,0.82,0.81,0.83,
           0.82,0.84,0.81,0.83,0.82,0.84,0.81,0.83,0.82,0.84,
           0.81,0.83,0.82,0.84,0.81,0.83,0.82,0.84,0.81,0.83,
           0.82,0.84,0.81,0.83,0.82,0.84,0.81,0.83,0.82,0.84],
    "MCI": [0.74,0.72,0.69,0.74,0.71,0.73,0.70,0.72,0.69,0.71,
            0.73,0.70,0.72,0.71,0.70,0.72,0.73,0.71,0.70,0.72,
            0.71,0.73,0.70,0.72,0.71,0.73,0.70,0.72,0.71,0.73,
            0.70,0.72,0.71,0.73,0.70,0.72,0.71,0.73,0.70,0.72,
            0.71,0.73,0.70,0.72,0.71,0.73,0.70,0.72,0.71,0.73],
    "ART": [0.89,0.91,0.88,0.90,0.87,0.89,0.88,0.90,0.87,0.88,
            0.89,0.87,0.89,0.88,0.87,0.89,0.90,0.88,0.87,0.89,
            0.88,0.90,0.87,0.89,0.88,0.90,0.87,0.89,0.88,0.90,
            0.87,0.89,0.88,0.90,0.87,0.89,0.88,0.90,0.87,0.89,
            0.88,0.90,0.87,0.89,0.88,0.90,0.87,0.89,0.88,0.90],
    "AR": [0.71,0.67,0.70,0.65,0.68,0.69,0.66,0.68,0.67,0.68,
           0.69,0.66,0.67,0.68,0.67,0.68,0.69,0.68,0.67,0.68,
           0.68,0.69,0.67,0.68,0.68,0.69,0.67,0.68,0.68,0.69,
           0.67,0.68,0.68,0.69,0.67,0.68,0.68,0.69,0.67,0.68,
           0.68,0.69,0.67,0.68,0.68,0.69,0.67,0.68,0.68,0.69],
    "TRI": [0.79,0.79,0.77,0.78,0.76,0.78,0.77,0.78,0.76,0.77,
            0.78,0.76,0.78,0.77,0.76,0.78,0.79,0.77,0.76,0.78,
            0.77,0.79,0.76,0.78,0.77,0.79,0.76,0.78,0.77,0.79,
            0.76,0.78,0.77,0.79,0.76,0.78,0.77,0.79,0.76,0.78,
            0.77,0.79,0.76,0.78,0.77,0.79,0.76,0.78,0.77,0.79]
}

df = pd.DataFrame(data)

# --- Step 3: Save CSV file
df.to_csv("FOB_locations.csv", index=False)
print("CSV file saved as FOB_locations.csv")

# --- Step 4: Display FOBs on interactive map
# Center map roughly over India
m = folium.Map(location=[22.5, 82.0], zoom_start=5)

# Add markers
for _, row in df.iterrows():
    popup_text = f"{row['FOB_Name']}<br>DL: {row['DL']}<br>MCI: {row['MCI']}<br>ART: {row['ART']}<br>AR: {row['AR']}<br>TRI: {row['TRI']}"
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
        icon=folium.Icon(color="blue", icon="info-sign")
    ).add_to(m)

# Save map to HTML
m.save("FOB_map.html")
print("Interactive map saved as FOB_map.html")

# --- Step 5: Display map inline in Colab
m
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.12/dist-packages (0.20.0)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from folium) (0.8.2)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.12/dist-packages (from folium) (3.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from folium) (2.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from folium) (2.32.4)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.12/dist-packages (from folium) (2026.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2>=2.9->folium) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->folium) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->folium) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->folium) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->folium) (2026.6.17)
# CSV file saved as FOB_locations.csv
# Interactive map saved as FOB_map.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_afec30c95a70728a31546c57e1e9a7a5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_afec30c95a70728a31546c57e1e9a7a5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_afec30c95a70728a31546c57e1e9a7a5 = L.map(
#                 &quot;map_afec30c95a70728a31546c57e1e9a7a5&quot;,
#                 {
#                     center: [22.5, 82.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a90b6923fbc21e641cd5775a01fd8008 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a90b6923fbc21e641cd5775a01fd8008.addTo(map_afec30c95a70728a31546c57e1e9a7a5);
#
#
#             var marker_654477b5162d3ec81f0ad284697a3944 = L.marker(
#                 [28.6139, 77.209],
#                 {
# }
#             ).addTo(map_afec30c95a70728a31546c57e1e9a7a5);
#
#
#             var icon_c89f1f6c293ee8196c114891e5c1a9ca = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_57b77fe010e22f92a4da56546b02d705 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_782258b0f8eb01002a06b26690195dbc = $(`&lt;div id=&quot;html_782258b0f8eb01002a06b26690195dbc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;FOB_001&lt;br&gt;DL: 0.82&lt;br&gt;MCI: 0.74&lt;br&gt;ART: 0.89&lt;br&gt;AR: 0.71&lt;br&gt;TRI: 0.79&lt;/div&gt;`)[0];
#                 popup_57b77fe010e22f92a4da56546b02d705.setContent(html_782258b0f8eb01002a06b26690195dbc);
#
#
#
#         marker_654477b5162d3ec81f0ad284697a3944.bindPopup(popup_57b77fe010e22f92a4da56546b02d705)
#         ;
#
#
#
#
#                 marker_654477b5162d3ec81f0ad284697a3944.setIcon(icon_c89f1f6c293ee8196c114891e5c1a9ca);
#
#
#             var marker_bac12685dad364855758d3fa621c0364 = L.marker(
#                 [19.076, 72.8777],
#                 {
# }
#             ).addTo(map_afec30c95a70728a31546c57e1e9a7a5);
#
#
#             var icon_7bca57919e90019eaf7f8ea1876c85e8 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_6211fa4c8cbfa82f24a63b25d0e809f4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fc2059011650117834787b54e814626d = $(`&lt;div id=&quot;html_fc2059011650117834787b54e814626d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;FOB_002&lt;br&gt;DL: 0.85&lt;br&gt;MCI: 0.72&lt;br&gt;ART: 0.91&lt;br&gt;AR: 0.67&lt;br&gt;TRI: 0.79&lt;/div&gt;`)[0];
#                 popup_6211fa4c8cbfa82f24a63b25d0e809f4.setContent(html_fc2059011650117834787b54e814626d);
#
#
#
#         marker_bac12685dad364855758d3fa621c0364.bindPopup(popup_6211fa4c8cbfa82f24a63b25d0e809f4)
#         ;
#
#
#
#
#                 marker_bac12685dad364855758d3fa621c0364.setIcon(icon_7bca57919e90019eaf7f8ea1876c85e8);
#
#
#             var marker_d267b79c1cd86eeb6450d3c7b5e9e799 = L.marker(
#                 [22.5726, 88.3639],
#                 {
# }
#             ).addTo(map_afec30c95a70728a31546c57e1e9a7a5);
#
#
#             var icon_31887cb6ba7b67ccf59c607e54d38bcf = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_36e5065b0c187b79d345487c9a6fd440 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_50858535ff861b4a7b0da3eb8647d36c = $(`&lt;div id=&quot;html_50858535ff861b4a7b0da3eb8647d36c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;FOB_003&lt;br&gt;DL: 0.81&lt;br&gt;MCI: 0.69&lt;br&gt;ART: 0.88&lt;br&gt;AR: 0.7&lt;br&gt;TRI: 0.77&lt;/div&gt;`)[0];
#                 popup_36e5065b0c187b79d345487c9a6fd440.setContent(html_50858535ff861b4a7b0da3eb8647d36c);
#
#
#
#         marker_d267b79c1cd86eeb6450d3c7b5e9e799.bindPopup(p
